# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import KFold
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, Conv1D, MaxPooling1D, GlobalMaxPooling1D, Dense, Dropout
from tensorflow.keras.optimizers import Adam
import matplotlib.pyplot as plt

# %%
# Memuat dataset
df = pd.read_csv('Dataset_Manual_stemming.csv', encoding='latin1', delimiter=';')
df.head()
# Out:
#    No     Type                                           Mentions  \
# 0   1       rt  RT @LANGKAHANIES: Jangan ada intervensi politi...
# 1   2       rt  RT @triwul82: Sejumlah perwakilan Koalisi Peru...
# 2   3       rt  RT @ajengcute16__: Merupakan Open Legal Policy...
# 3   4       rt  RT @Jatayu_45: JOKOWI HARUS MUNDUR DARI JABATA...
# 4   5  mention  Langkahi Presiden dan DPR, Demokrat: Bukan Wew...
#
#                Date    Media Sentiment  \
# 0  31/05/2023 23:59  Twitter  Positive
# 1  31/05/2023 23:59  Twitter  Negative
# 2  31/05/2023 23:59  Twitter  Positive
# 3  31/05/2023 23:59  Twitter   Neutral
# 4  31/05/2023 23:59  Twitter  Negative
#
#                                               Author  Followers  Retweeted  \
# 0                     @YTrigusmintara (ManusiaBebas)       19.0       64.0
# 1  @INA_NKRI (100% Indonesia ÃÂÃÂÃÂÃÂ°ÃÂ...     1250.0       83.0
# 2                              @sri08054 (Sri anies)      356.0       50.0
# 3                      @wongedan1708 (BAGong Modern)       16.0      108.0
# 4                @Simanjunta9Nico (Nico Simanjuntak)      650.0        0.0
#
#    Favourited                                          Mentions1 Sentiment1  \
# 0         0.0  jangan ada intervensi politik penjegalan pilpr...    negatif
# 1         0.0  sejumlah perwakilan koalisi perubahan yang men...    positif
# 2         0.0  merupakan open legal policy perludem sangat be...    negatif
# 3         0.0  jokowi harus mundur dari jabatan presiden kala...    negatif
# 4         0.0  langkahi presiden dan dpr demokrat bukan wewen...    negatif
#
#                                         stemmed_text
# 0  jangan ada intervensi politik jegal pilpres 20...
# 1  jumlah wakil koalisi ubah yang usung anies bag...
# 2  rupa open legal policy perludem sangat bahaya ...
# 3  jokowi harus mundur dari jabat presiden kalau ...
# 4  langkah presiden dan dpr demokrat bukan wewena...

# %%
# Memastikan dataset yang digunakan berupa string
df['stemmed_text'] = df['stemmed_text'].fillna('').astype(str)

# %%
# Memberi kode pada label
label_encoder = LabelEncoder()
df['Sentiment1'] = label_encoder.fit_transform(df['Sentiment1'])

# %%
# Tokenize dan padding
vocab_size = 10000
embedding_dim = 128
max_length = 200

tokenizer = Tokenizer(num_words=vocab_size, oov_token='<OOV>')
tokenizer.fit_on_texts(df['stemmed_text'])
sequences = tokenizer.texts_to_sequences(df['stemmed_text'])
padded_sequences = pad_sequences(sequences, maxlen=max_length, padding='post', truncating='post')

# %%
# Mempersiapkan labels
labels = to_categorical(df['Sentiment1'])

# %%
# Definisikan model CNN
def create_model(vocab_size, embedding_dim, max_length):
    model = Sequential([
        Embedding(input_dim=vocab_size, output_dim=embedding_dim, input_length=max_length),
        Conv1D(filters=128, kernel_size=5, activation='relu'),
        MaxPooling1D(pool_size=2),
        Conv1D(filters=128, kernel_size=5, activation='relu'),
        MaxPooling1D(pool_size=2),
        Conv1D(filters=128, kernel_size=5, activation='relu'),
        GlobalMaxPooling1D(),
        Dense(128, activation='relu'),
        Dropout(0.5),
        Dense(3, activation='softmax')
    ])
    return model

# %%
# K-Fold Cross Validation
k = 5
kf = KFold(n_splits=k, shuffle=True, random_state=42)
cvscores = []

for train_index, test_index in kf.split(padded_sequences):
    X_train, X_val = padded_sequences[train_index], padded_sequences[test_index]
    y_train, y_val = labels[train_index], labels[test_index]
    
    model = create_model(vocab_size, embedding_dim, max_length)
    model.compile(optimizer=Adam(learning_rate=0.001), loss='categorical_crossentropy', metrics=['accuracy'])
    
    history = model.fit(X_train, y_train, epochs=20, batch_size=32, validation_data=(X_val, y_val), verbose=1)   
    # Evaluasi model pada data validasi
    loss, accuracy = model.evaluate(X_val, y_val, verbose=0)
    cvscores.append(accuracy * 100)
    # Prediksi data validasi
    y_pred_prob = model.predict(X_val)
    y_pred = np.argmax(y_pred_prob, axis=1)
    y_true = np.argmax(y_val, axis=1)
# Out:
# Epoch 1/20
# C:\Users\ASUS\anaconda3\Lib\site-packages\keras\src\layers\core\embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 9s 36ms/step - accuracy: 0.5597 - loss: 0.8842 - val_accuracy: 0.8560 - val_loss: 0.3843
# Epoch 2/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 34ms/step - accuracy: 0.9073 - loss: 0.2670 - val_accuracy: 0.8840 - val_loss: 0.3094
# Epoch 3/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - accuracy: 0.9685 - loss: 0.1095 - val_accuracy: 0.8960 - val_loss: 0.3887
# Epoch 4/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 33ms/step - accuracy: 0.9864 - loss: 0.0613 - val_accuracy: 0.8880 - val_loss: 0.4068
# Epoch 5/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 34ms/step - accuracy: 0.9859 - loss: 0.0614 - val_accuracy: 0.8960 - val_loss: 0.4481
# Epoch 6/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 33ms/step - accuracy: 0.9882 - loss: 0.0533 - val_accuracy: 0.8970 - val_loss: 0.3787
# Epoch 7/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 34ms/step - accuracy: 0.9885 - loss: 0.0469 - val_accuracy: 0.8960 - val_loss: 0.4754
# Epoch 8/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 5s 36ms/step - accuracy: 0.9909 - loss: 0.0364 - val_accuracy: 0.9010 - val_loss: 0.4445
# Epoch 9/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 34ms/step - accuracy: 0.9893 - loss: 0.0295 - val_accuracy: 0.8980 - val_loss: 0.4727
# Epoch 10/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 34ms/step - accuracy: 0.9932 - loss: 0.0287 - val_accuracy: 0.9020 - val_loss: 0.4923
# Epoch 11/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 34ms/step - accuracy: 0.9933 - loss: 0.0263 - val_accuracy: 0.8990 - val_loss: 0.5732
# Epoch 12/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 33ms/step - accuracy: 0.9926 - loss: 0.0288 - val_accuracy: 0.8930 - val_loss: 0.5614
# Epoch 13/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 33ms/step - accuracy: 0.9922 - loss: 0.0284 - val_accuracy: 0.8870 - val_loss: 0.5831
# Epoch 14/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 33ms/step - accuracy: 0.9909 - loss: 0.0287 - val_accuracy: 0.8980 - val_loss: 0.6562
# Epoch 15/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 33ms/step - accuracy: 0.9955 - loss: 0.0200 - val_accuracy: 0.8870 - val_loss: 0.5236
# Epoch 16/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 34ms/step - accuracy: 0.9901 - loss: 0.0261 - val_accuracy: 0.8950 - val_loss: 0.6962
# Epoch 17/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 33ms/step - accuracy: 0.9942 - loss: 0.0212 - val_accuracy: 0.8890 - val_loss: 0.7232
# Epoch 18/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 35ms/step - accuracy: 0.9951 - loss: 0.0179 - val_accuracy: 0.8870 - val_loss: 0.6668
# Epoch 19/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 35ms/step - accuracy: 0.9935 - loss: 0.0216 - val_accuracy: 0.8980 - val_loss: 0.7808
# Epoch 20/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 35ms/step - accuracy: 0.9923 - loss: 0.0249 - val_accuracy: 0.9010 - val_loss: 0.9319
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step
# Epoch 1/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 9s 39ms/step - accuracy: 0.5561 - loss: 0.8777 - val_accuracy: 0.8670 - val_loss: 0.3508
# Epoch 2/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 34ms/step - accuracy: 0.9127 - loss: 0.2501 - val_accuracy: 0.8790 - val_loss: 0.3402
# Epoch 3/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 34ms/step - accuracy: 0.9705 - loss: 0.1113 - val_accuracy: 0.8830 - val_loss: 0.3733
# Epoch 4/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 33ms/step - accuracy: 0.9809 - loss: 0.0756 - val_accuracy: 0.8940 - val_loss: 0.3836
# Epoch 5/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 34ms/step - accuracy: 0.9902 - loss: 0.0482 - val_accuracy: 0.8670 - val_loss: 0.4743
# Epoch 6/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 35ms/step - accuracy: 0.9879 - loss: 0.0497 - val_accuracy: 0.8930 - val_loss: 0.4253
# Epoch 7/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 5s 38ms/step - accuracy: 0.9913 - loss: 0.0340 - val_accuracy: 0.8830 - val_loss: 0.4926
# Epoch 8/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 5s 36ms/step - accuracy: 0.9920 - loss: 0.0363 - val_accuracy: 0.8860 - val_loss: 0.5048
# Epoch 9/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 5s 42ms/step - accuracy: 0.9931 - loss: 0.0314 - val_accuracy: 0.8860 - val_loss: 0.5116
# Epoch 10/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 5s 41ms/step - accuracy: 0.9917 - loss: 0.0312 - val_accuracy: 0.8900 - val_loss: 0.4880
# Epoch 11/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 5s 38ms/step - accuracy: 0.9917 - loss: 0.0271 - val_accuracy: 0.8880 - val_loss: 0.5591
# Epoch 12/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - accuracy: 0.9928 - loss: 0.0233 - val_accuracy: 0.8800 - val_loss: 0.5425
# Epoch 13/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - accuracy: 0.9947 - loss: 0.0203 - val_accuracy: 0.8800 - val_loss: 0.6071
# Epoch 14/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 5s 38ms/step - accuracy: 0.9921 - loss: 0.0261 - val_accuracy: 0.8820 - val_loss: 0.6666
# Epoch 15/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 5s 38ms/step - accuracy: 0.9928 - loss: 0.0276 - val_accuracy: 0.8880 - val_loss: 0.7180
# Epoch 16/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - accuracy: 0.9931 - loss: 0.0218 - val_accuracy: 0.8850 - val_loss: 0.6025
# Epoch 17/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 5s 38ms/step - accuracy: 0.9937 - loss: 0.0261 - val_accuracy: 0.8760 - val_loss: 0.6905
# Epoch 18/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 5s 41ms/step - accuracy: 0.9935 - loss: 0.0235 - val_accuracy: 0.8770 - val_loss: 0.6629
# Epoch 19/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 5s 41ms/step - accuracy: 0.9931 - loss: 0.0257 - val_accuracy: 0.8810 - val_loss: 0.8588
# Epoch 20/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 5s 42ms/step - accuracy: 0.9907 - loss: 0.0267 - val_accuracy: 0.8790 - val_loss: 0.7840
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step
# Epoch 1/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 10s 45ms/step - accuracy: 0.5621 - loss: 0.8753 - val_accuracy: 0.8248 - val_loss: 0.4224
# Epoch 2/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - accuracy: 0.9232 - loss: 0.2432 - val_accuracy: 0.8689 - val_loss: 0.3627
# Epoch 3/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - accuracy: 0.9733 - loss: 0.1112 - val_accuracy: 0.8799 - val_loss: 0.4574
# Epoch 4/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 5s 42ms/step - accuracy: 0.9823 - loss: 0.0762 - val_accuracy: 0.8699 - val_loss: 0.4923
# Epoch 5/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 5s 38ms/step - accuracy: 0.9897 - loss: 0.0441 - val_accuracy: 0.8769 - val_loss: 0.4495
# Epoch 6/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 5s 37ms/step - accuracy: 0.9887 - loss: 0.0524 - val_accuracy: 0.8729 - val_loss: 0.5014
# Epoch 7/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 5s 38ms/step - accuracy: 0.9933 - loss: 0.0305 - val_accuracy: 0.8699 - val_loss: 0.8500
# Epoch 8/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 5s 44ms/step - accuracy: 0.9901 - loss: 0.0397 - val_accuracy: 0.8729 - val_loss: 0.5680
# Epoch 9/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 5s 42ms/step - accuracy: 0.9907 - loss: 0.0308 - val_accuracy: 0.8739 - val_loss: 0.7415
# Epoch 10/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 5s 41ms/step - accuracy: 0.9894 - loss: 0.0327 - val_accuracy: 0.8709 - val_loss: 0.8135
# Epoch 11/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 5s 43ms/step - accuracy: 0.9903 - loss: 0.0355 - val_accuracy: 0.8609 - val_loss: 0.6348
# Epoch 12/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - accuracy: 0.9897 - loss: 0.0395 - val_accuracy: 0.8719 - val_loss: 0.5405
# Epoch 13/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 5s 41ms/step - accuracy: 0.9885 - loss: 0.0398 - val_accuracy: 0.8769 - val_loss: 0.7250
# Epoch 14/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - accuracy: 0.9914 - loss: 0.0295 - val_accuracy: 0.8699 - val_loss: 0.8545
# Epoch 15/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 5s 38ms/step - accuracy: 0.9928 - loss: 0.0277 - val_accuracy: 0.8689 - val_loss: 0.8005
# Epoch 16/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - accuracy: 0.9916 - loss: 0.0243 - val_accuracy: 0.8689 - val_loss: 0.9274
# Epoch 17/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - accuracy: 0.9906 - loss: 0.0264 - val_accuracy: 0.8739 - val_loss: 0.8960
# Epoch 18/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 5s 38ms/step - accuracy: 0.9925 - loss: 0.0235 - val_accuracy: 0.8779 - val_loss: 0.8839
# Epoch 19/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - accuracy: 0.9907 - loss: 0.0267 - val_accuracy: 0.8679 - val_loss: 1.0763
# Epoch 20/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 5s 41ms/step - accuracy: 0.9941 - loss: 0.0172 - val_accuracy: 0.8689 - val_loss: 1.0031
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step
# Epoch 1/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 10s 44ms/step - accuracy: 0.5810 - loss: 0.8633 - val_accuracy: 0.8579 - val_loss: 0.3552
# Epoch 2/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 5s 41ms/step - accuracy: 0.9289 - loss: 0.2307 - val_accuracy: 0.8919 - val_loss: 0.3250
# Epoch 3/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - accuracy: 0.9758 - loss: 0.0945 - val_accuracy: 0.8939 - val_loss: 0.3623
# Epoch 4/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - accuracy: 0.9817 - loss: 0.0704 - val_accuracy: 0.8899 - val_loss: 0.4018
# Epoch 5/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 5s 41ms/step - accuracy: 0.9894 - loss: 0.0395 - val_accuracy: 0.8819 - val_loss: 0.4425
# Epoch 6/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - accuracy: 0.9901 - loss: 0.0315 - val_accuracy: 0.8909 - val_loss: 0.3778
# Epoch 7/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 5s 41ms/step - accuracy: 0.9912 - loss: 0.0383 - val_accuracy: 0.8899 - val_loss: 0.4769
# Epoch 8/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - accuracy: 0.9882 - loss: 0.0354 - val_accuracy: 0.8959 - val_loss: 0.4829
# Epoch 9/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 5s 41ms/step - accuracy: 0.9918 - loss: 0.0286 - val_accuracy: 0.8819 - val_loss: 0.5812
# Epoch 10/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - accuracy: 0.9944 - loss: 0.0216 - val_accuracy: 0.8919 - val_loss: 0.5359
# Epoch 11/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - accuracy: 0.9938 - loss: 0.0240 - val_accuracy: 0.8889 - val_loss: 0.6025
# Epoch 12/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 5s 41ms/step - accuracy: 0.9895 - loss: 0.0287 - val_accuracy: 0.8899 - val_loss: 0.6392
# Epoch 13/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 5s 38ms/step - accuracy: 0.9897 - loss: 0.0301 - val_accuracy: 0.8939 - val_loss: 0.6325
# Epoch 14/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - accuracy: 0.9921 - loss: 0.0231 - val_accuracy: 0.8859 - val_loss: 0.8179
# Epoch 15/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - accuracy: 0.9946 - loss: 0.0204 - val_accuracy: 0.8909 - val_loss: 0.7386
# Epoch 16/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 5s 38ms/step - accuracy: 0.9902 - loss: 0.0254 - val_accuracy: 0.8929 - val_loss: 0.7374
# Epoch 17/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 5s 37ms/step - accuracy: 0.9928 - loss: 0.0249 - val_accuracy: 0.8809 - val_loss: 0.8055
# Epoch 18/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 5s 41ms/step - accuracy: 0.9802 - loss: 0.0530 - val_accuracy: 0.8749 - val_loss: 0.5877
# Epoch 19/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - accuracy: 0.9827 - loss: 0.0578 - val_accuracy: 0.8839 - val_loss: 0.6946
# Epoch 20/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - accuracy: 0.9861 - loss: 0.0406 - val_accuracy: 0.8899 - val_loss: 0.7348
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step
# Epoch 1/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 9s 41ms/step - accuracy: 0.5400 - loss: 0.8965 - val_accuracy: 0.8539 - val_loss: 0.3722
# Epoch 2/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 5s 42ms/step - accuracy: 0.9182 - loss: 0.2397 - val_accuracy: 0.8989 - val_loss: 0.2836
# Epoch 3/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 6s 45ms/step - accuracy: 0.9687 - loss: 0.1220 - val_accuracy: 0.8899 - val_loss: 0.3155
# Epoch 4/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 5s 41ms/step - accuracy: 0.9824 - loss: 0.0695 - val_accuracy: 0.8989 - val_loss: 0.3874
# Epoch 5/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 5s 41ms/step - accuracy: 0.9883 - loss: 0.0458 - val_accuracy: 0.8959 - val_loss: 0.3638
# Epoch 6/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 5s 42ms/step - accuracy: 0.9897 - loss: 0.0433 - val_accuracy: 0.9039 - val_loss: 0.4077
# Epoch 7/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - accuracy: 0.9893 - loss: 0.0412 - val_accuracy: 0.8939 - val_loss: 0.4260
# Epoch 8/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - accuracy: 0.9900 - loss: 0.0314 - val_accuracy: 0.9019 - val_loss: 0.4829
# Epoch 9/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 5s 41ms/step - accuracy: 0.9899 - loss: 0.0366 - val_accuracy: 0.9059 - val_loss: 0.5742
# Epoch 10/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - accuracy: 0.9905 - loss: 0.0306 - val_accuracy: 0.8949 - val_loss: 0.4913
# Epoch 11/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - accuracy: 0.9904 - loss: 0.0260 - val_accuracy: 0.8899 - val_loss: 0.5237
# Epoch 12/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 5s 42ms/step - accuracy: 0.9927 - loss: 0.0257 - val_accuracy: 0.8989 - val_loss: 0.6729
# Epoch 13/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 5s 42ms/step - accuracy: 0.9900 - loss: 0.0251 - val_accuracy: 0.8939 - val_loss: 0.7288
# Epoch 14/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - accuracy: 0.9906 - loss: 0.0258 - val_accuracy: 0.8929 - val_loss: 0.6045
# Epoch 15/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 5s 41ms/step - accuracy: 0.9917 - loss: 0.0261 - val_accuracy: 0.8829 - val_loss: 0.7153
# Epoch 16/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 5s 41ms/step - accuracy: 0.9929 - loss: 0.0219 - val_accuracy: 0.8919 - val_loss: 0.7190
# Epoch 17/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - accuracy: 0.9899 - loss: 0.0268 - val_accuracy: 0.8949 - val_loss: 0.8743
# Epoch 18/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 5s 41ms/step - accuracy: 0.9908 - loss: 0.0305 - val_accuracy: 0.8759 - val_loss: 0.7289
# Epoch 19/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 5s 41ms/step - accuracy: 0.9891 - loss: 0.0383 - val_accuracy: 0.8909 - val_loss: 0.6579
# Epoch 20/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 5s 41ms/step - accuracy: 0.9872 - loss: 0.0380 - val_accuracy: 0.8709 - val_loss: 0.6802
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step

# %%
# Prediksi data validasi
y_pred_prob = model.predict(X_val)
y_pred = np.argmax(y_pred_prob, axis=1)
y_true = np.argmax(y_val, axis=1)
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step

# %%
# Rata-rata akurasi dari semua fold
print(f"Mean Accuracy: {np.mean(cvscores):.2f}%\n")
print(classification_report(y_true, y_pred, target_names=label_encoder.classes_))
# Out:
# Mean Accuracy: 88.19%
#
#               precision    recall  f1-score   support
#
#      negatif       0.81      0.93      0.86       306
#       netral       0.88      0.87      0.87       293
#      positif       0.93      0.82      0.87       400
#
#     accuracy                           0.87       999
#    macro avg       0.87      0.88      0.87       999
# weighted avg       0.88      0.87      0.87       999
